# %%
# !wget https://raw.githubusercontent.com/CIERA-Northwestern/REACHpy/main/Module_2/data/exoplanets_subset.txt

import numpy as np
import matplotlib.pyplot as plt

exodata = np.loadtxt('exoplanets_subset.txt' , usecols=(0,2))

radii = exodata[:,0]
periods = exodata[:,1]

plot = plt.scatter(periods, radii, c= 'pink')
plt.xscale('log')
plt.yscale('log')
plt.title('Planetary Radii vs Orbital Period')
plt.xlabel('Orbital Period')
plt.ylabel('Planetary Radii')
# Out:
# --2024-06-13 16:25:38--  https://raw.githubusercontent.com/CIERA-Northwestern/REACHpy/main/Module_2/data/exoplanets_subset.txt
# Resolving raw.githubusercontent.com (raw.githubusercontent.com)... 185.199.109.133, 185.199.110.133, 185.199.111.133, ...
# Connecting to raw.githubusercontent.com (raw.githubusercontent.com)|185.199.109.133|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 16581 (16K) [text/plain]
# Saving to: ‘exoplanets_subset.txt’
#
# exoplanets_subset.t 100%[===================>]  16.19K  --.-KB/s    in 0.001s
#
# 2024-06-13 16:25:38 (21.9 MB/s) - ‘exoplanets_subset.txt’ saved [16581/16581]
# Text(0, 0.5, 'Planetary Radii')
